# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jason, Data Scientist**

# %% [markdown]
# *I am interested in data science because understanding data and being a part of an effort to make data-driven decisions is very rewarding work.*

# %% [markdown]
# ### The code in Cell 5 will add 1 plus 2 plus 3.

# %%
1+2+3
# Out:
# 6

# %% [markdown]
# ***
# 1. The three numbers add up to six.
# 2. You can calculate this using the online calulator linked here:(https://www.online-calculator.com/).
# 3. See table below for number tabulation.
# ***
# | Number 1 | Number 2 | Number 3 |
# | ---- | ---- | ---- |
# | 1 | 2 | 3 |
